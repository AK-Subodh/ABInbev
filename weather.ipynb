# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
## Reading csv file 

data=pd.read_csv('weather_data_.csv')

# %%
## Making a copy of original data for backup

data_original=data.copy()

# %% [markdown]
# ## Getting to Know the dataset

# %%
## Checking the first 5 rows of th data in order to get a view and develop understanding

data.head()
# Out:
#    time      date  tempC  windspeedMiles  windspeedKmph  winddirDegree  \
# 0     0  1/1/2019      9               6             10            272
# 1   300  1/1/2019      8               7             11            278
# 2   600  1/1/2019      7               8             12            284
# 3   900  1/1/2019      7               8             13            294
# 4  1200  1/1/2019      9               9             15            320
#
#   winddir16Point  weatherCode    weatherDesc  precipMM  precipInches  \
# 0              W          122       Overcast       0.0           0.0
# 1              W          116  Partly cloudy       0.0           0.0
# 2            WNW          113          Sunny       0.0           0.0
# 3            WNW          116  Partly cloudy       0.0           0.0
# 4             NW          116  Partly cloudy       0.0           0.0
#
#    humidity  visibility  visibilityMiles  pressure  pressureInches  \
# ...

# %%
## Total number of rows and columns in the data set

data.shape
# Out:
# (8768, 20)

# %%
## Getting the list of names of all the columns present in the dataset

data.columns
# Out:
# Index(['time', 'date', 'tempC', 'windspeedMiles', 'windspeedKmph',
#        'winddirDegree', 'winddir16Point', 'weatherCode', 'weatherDesc',
#        'precipMM', 'precipInches', 'humidity', 'visibility', 'visibilityMiles',
#        'pressure', 'pressureInches', 'cloudcover', 'WindGustMiles',
#        'WindGustKmph', 'uvIndex'],
#       dtype='object')

# %%
## CHecking the information of the attributes like data type, total entries,etc.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8768 entries, 0 to 8767
# Data columns (total 20 columns):
# time               8768 non-null int64
# date               8768 non-null object
# tempC              8768 non-null int64
# windspeedMiles     8768 non-null int64
# windspeedKmph      8768 non-null int64
# winddirDegree      8768 non-null int64
# winddir16Point     8768 non-null object
# weatherCode        8768 non-null int64
# weatherDesc        8768 non-null object
# precipMM           8768 non-null float64
# precipInches       8768 non-null float64
# humidity           8768 non-null int64
# visibility         8768 non-null int64
# visibilityMiles    8768 non-null int64
# pressure           8768 non-null int64
# pressureInches     8768 non-null int64
# cloudcover         8768 non-null int64
# WindGustMiles      8768 non-null int64
# WindGustKmph       8768 non-null int64
# uvIndex            8768 non-null int64
# dtypes: float64(2), int64(15), object(3)
# ...

# %%
## Checking the spread of the numerical attributes

data.describe()
# Out:
#               time        tempC  windspeedMiles  windspeedKmph  winddirDegree  \
# count  8768.000000  8768.000000     8768.000000    8768.000000    8768.000000
# mean   1050.000000    12.473312        8.747833      14.071168     194.331432
# std     687.425556     5.994672        4.592800       7.361726      96.386032
# min       0.000000    -7.000000        0.000000       0.000000       0.000000
# 25%     525.000000     8.000000        5.000000       9.000000     107.000000
# 50%    1050.000000    12.000000        8.000000      13.000000     219.000000
# 75%    1575.000000    17.000000       11.000000      18.000000     262.000000
# max    2100.000000    36.000000       31.000000      50.000000     360.000000
#
#        weatherCode     precipMM  precipInches     humidity   visibility  \
# count  8768.000000  8768.000000   8768.000000  8768.000000  8768.000000
# mean    157.332801     0.313777      0.010059    70.176209     9.371693
# ...

# %%
## Checking the number of null values in each column

data.isnull().sum()
# Out:
# time               0
# date               0
# tempC              0
# windspeedMiles     0
# windspeedKmph      0
# winddirDegree      0
# winddir16Point     0
# weatherCode        0
# weatherDesc        0
# precipMM           0
# precipInches       0
# humidity           0
# visibility         0
# visibilityMiles    0
# pressure           0
# pressureInches     0
# cloudcover         0
# WindGustMiles      0
# WindGustKmph       0
# uvIndex            0
# dtype: int64

# %% [markdown]
# ### Conclusion so far
# As we could see, our dataset contains total of 8768 rows and 20 columns. We checked the column names present in the dataset and then checked the total number of null values which is zero. SO the dataset does not have any missing values.
#
# But as the data type for the columns is not correctly assigned, leaving it as it is may cause problems in dealing with them later. For example, time is in int and date is described as 'object'. We need to perform type conversion. For this we need to have close look at the columns of the dataset and then decide which data type should be assigned to them.
#
# | Sr. No.    | Name | Description  | Current Data Type  | New Data Type  | Conversion Needed? | Detailed Description  |
# | :---       |    :----:   | :---        |    :----:   |    :----:   |    :----:   | :---        |
# | 1 | time  | Hour of the day | int64 | datetime | Yes | - |
# | 2 | date  | Date of reading | object | datetime | Yes | - |
# | 3 | tempC | Temp. in deg. Celsius | int64 | int64 | NO | Atmospheric Temperature |
# | 4 | windspeedMiles | Wind speed in miles/hr | int64 | int64 | NO | wind speed, or wind flow speed, is a fundamental atmospheric quantity caused by air moving from high to low pressure, usually due to changes in temperature.  |
# | 5 | windspeedKmph | Wind speed in Km/hr | int64 | int64 | NO | wind speed, or wind flow speed, is a fundamental atmospheric quantity caused by air moving from high to low pressure, usually due to changes in temperature.  |
# | 6 | winddirDegree | Wind Direction in degrees | int64 | int64 | NO | Wind direction is generally reported by the direction from which it originates. Reading is in degrees here. |
# | 7 | winddir16Point | Wind Direction in 16 point compass | object | Category | Yes | Wind direction is generally reported by the direction from which it originates. 16 point compass reading is used here. |
# | 8 | weatherCode | Code assigned to weather | int64 | category | Yes | - |
# | 9 | weatherDesc | Weather description | object | category | Yes | Cloudy, sunny, etc. |
# | 10 | precipMM  | Precipitation in mm | float64 | float64 | NO | precipitation is any product of the condensation of atmospheric water vapor that falls under gravitational pull from clouds. The main forms of precipitation include drizzling, rain, sleet, snow, ice pellets, graupel and hail. |
# | 11 | precipInches | Precipitation in inches | float64 | float64 | NO | precipitation is any product of the condensation of atmospheric water vapor that falls under gravitational pull from clouds. The main forms of precipitation include drizzling, rain, sleet, snow, ice pellets, graupel and hail. |
# | 12 | humidity | Humidity in % | int64 | int64 | NO | Humidity is a measure of the amount of water vapor in the air. |
# | 13 | visibility | Visibility in Km | int64 | int64 | NO | Visibility is a measure of the horizontal opacity of the atmosphere at the point of observation and is expressed in terms of the horizontal distance at which a person should be able to see and identify |
# | 14 | visibilityMiles | Visibility in miles | int64 | int64 | NO | Visibility is a measure of the horizontal opacity of the atmosphere at the point of observation and is expressed in terms of the horizontal distance at which a person should be able to see and identify |
# | 15 | pressure | Pressure in mmHg | int64 | int64 | NO | Atmospheric pressure, also known as barometric pressure, is the pressure within the atmosphere of Earth |
# | 16 | pressureInches | Pressure in inches of Hg | int64 | int64 | NO | Atmospheric pressure, also known as barometric pressure, is the pressure within the atmosphere of Earth |
# | 17 | cloudcover | Cloud cover in % | int64 | int64 | NO | A gust or wind gust is a brief increase in the speed of the wind, usually less than 20 seconds. |
# | 18 | WindGustMiles | Wind Gust speed in Miles/hr | int64 | int64 | NO |
# | 19 | WindGustKmph | Wind Gust speed in Km/hr | int64 | int64 | NO | A gust or wind gust is a brief increase in the speed of the wind, usually less than 20 seconds. |
# | 20 | uvIndex | UV Index | int64 | int64 | NO | The UV index tells you how much ultraviolet radiation is around at ground level on a given day, and its potential to harm your skin.|

# %% [markdown]
#  Some of the columns and values in them seem to be confusing as their spread seem somewhat constant. So, let's take a closer look at them just to check.
#
#  Column names :
#  - visibility
#  - visibilityMiles

# %%
## Checking the number of unique values in both the columns

print('Visibility Unique values: ',data['visibility'].unique())
print('Visibility (Miles)Unique Values: ',data['visibilityMiles'].unique())
print('Visibility number of observations for each category: ',data['visibility'].value_counts())
print('Visibility (Miles) number of observations for each category: ',data['visibilityMiles'].value_counts())
# Out:
# Visibility Unique values:  [10  9  2  5  7  0  6  8  3]
# Visibility (Miles)Unique Values:  [6 5 1 3 4 0]
# Visibility number of observations for each category:  10    7402
# 9      552
# 2      411
# 7      238
# 5       80
# 0       42
# 8       23
# 6       17
# 3        3
# Name: visibility, dtype: int64
# Visibility (Miles) number of observations for each category:  6    7402
# 5     552
# 1     414
# 4     261
# 3      97
# 0      42
# Name: visibilityMiles, dtype: int64

# %% [markdown]
# Sufficient observations have different values, so no issue in these rows.

# %% [markdown]
# Next,
#
# Column names:
# - winddir16Point
# - winddirDegree
#
# Here, I want to check the unique number of values that are there in each of these.
#
# While wind direction could be a very specific number (when specified in degrees), there are only 16 categories in 16 point compass measurement.
#
# For the Feature selection part, we might not need to keep 'degrees' value of the wind direction and the broader category of 16 point compass can be proved to be useful after being encoded.

# %%
print('Wind Direction (16 point ) Unique values: ',data['winddir16Point'].unique())
print('Wind Direction (16 point ) number of observations for each category: ',data['winddir16Point'].value_counts())
print('Wind Direction (degrees) total Unique values: ',len(data['winddirDegree'].unique()))
print('Wind Direction (degrees ) number of observations for each category: ',data['winddirDegree'].value_counts())
# Out:
# Wind Direction (16 point ) Unique values:  ['W' 'WNW' 'NW' 'NNW' 'NNE' 'N' 'WSW' 'SW' 'S' 'SSE' 'SE' 'ESE' 'E' 'NE'
#  'SSW' 'ENE']
# Wind Direction (16 point ) number of observations for each category:  SW     1129
# WSW    1119
# SSW     856
# W       798
# WNW     550
# NNE     519
# ENE     477
# NE      462
# S       455
# E       454
# NNW     433
# N       383
# NW      359
# SSE     271
# ESE     262
# SE      241
# Name: winddir16Point, dtype: int64
# Wind Direction (degrees) total Unique values:  361
# Wind Direction (degrees ) number of observations for each category:  236    70
# 244    65
# 246    63
# 239    60
# 231    60
#        ..
# 137     6
# 121     6
# 124     5
# 120     4
# 122     4
# Name: winddirDegree, Length: 361, dtype: int64

# %% [markdown]
# As suspected, wind direction (in degrees) has 361 unique values.
#
# Next,
#
# Column names:
# - weatherCode
# - weatherDesc
#
# Again, I want to check if the code assigned is the code for weather description itself or something else.

# %%
print('weatherCode Unique values: ',data['weatherCode'].unique())
print('weatherCode number of observations : ',len(data['weatherCode'].unique()))
print('weatherDesc total Unique values: ',data['weatherDesc'].unique())
print('weatherDesc number of observations : ',len(data['weatherDesc'].unique()))
# Out:
# weatherCode Unique values:  [122 116 113 176 119 143 266 263 329 302 182 200 353 230 338 368 332 317
#  335 326 296 248 308 293 389 356 299 305 311 227 359 386 320 362 371 395
#  323]
# weatherCode number of observations :  37
# weatherDesc total Unique values:  ['Overcast' 'Partly cloudy' 'Sunny' 'Patchy rain possible' 'Clear'
#  'Cloudy' 'Mist' 'Light drizzle' 'Patchy light drizzle'
#  'Patchy moderate snow' 'Moderate rain' 'Patchy sleet possible'
#  'Thundery outbreaks possible' 'Light rain shower' 'Blizzard' 'Heavy snow'
#  'Light snow showers' 'Moderate snow' 'Light sleet' 'Patchy heavy snow'
#  'Light snow' 'Light rain' 'Fog' 'Heavy rain' 'Patchy light rain'
#  'Moderate or heavy rain with thunder' 'Moderate or heavy rain shower'
#  'Moderate rain at times' 'Heavy rain at times' 'Light freezing rain'
#  'Blowing snow' 'Torrential rain shower' 'Patchy light rain with thunder'
#  'Moderate or heavy sleet' 'Light sleet showers'
# ...

# %% [markdown]
# Weather Code has one value less than the weather description. Hence, both can't be same.
# Before eliminating one of them, we'll have to check the correlation between these columns. If it is vary high then we can use only one of the as the substituent of the other.

# %% [markdown]
# ## Feature Engineering
#
# ### Type Conversion

# %%
## Before converting the date, we need to check the format of the date

data['date'].sample(10)
# Out:
# 2245     10/8/2019
# 3398     2/29/2020
# 5060     9/24/2020
# 1064     5/14/2019
# 8725    12/26/2021
# 6756     4/24/2021
# 4044     5/20/2020
# 6437     3/15/2021
# 214      1/27/2019
# 612      3/18/2019
# Name: date, dtype: object

# %%
## From above, we know that the format of the date is %m/%d/%Y
## time is in int, we need to concate with the date to create the timestamp

data['time']=data['time']/100
data['time']=data['time'].astype('int')
data['time']=data['time'].apply(str)
data['date_time']=pd.to_datetime(data['date'] + data['time'], format='%m/%d/%Y%H')
data.head(10)
# Out:
#   time      date  tempC  windspeedMiles  windspeedKmph  winddirDegree  \
# 0    0  1/1/2019      9               6             10            272
# 1    3  1/1/2019      8               7             11            278
# 2    6  1/1/2019      7               8             12            284
# 3    9  1/1/2019      7               8             13            294
# 4   12  1/1/2019      9               9             15            320
# 5   15  1/1/2019     10               7             12            338
# 6   18  1/1/2019      9               7             12             13
# 7   21  1/1/2019      7               8             13             15
# 8    0  1/2/2019      6               8             12             11
# 9    3  1/2/2019      4               8             13            356
#
#   winddir16Point  weatherCode           weatherDesc  precipMM  ...  humidity  \
# 0              W          122              Overcast       0.0  ...        78
# ...

# %%
data.dtypes
# Out:
# time                       object
# date                       object
# tempC                       int64
# windspeedMiles              int64
# windspeedKmph               int64
# winddirDegree               int64
# winddir16Point             object
# weatherCode                 int64
# weatherDesc                object
# precipMM                  float64
# precipInches              float64
# humidity                    int64
# visibility                  int64
# visibilityMiles             int64
# pressure                    int64
# pressureInches              int64
# cloudcover                  int64
# WindGustMiles               int64
# WindGustKmph                int64
# uvIndex                     int64
# date_time          datetime64[ns]
# dtype: object

# %%
data['month']=data['date_time'].dt.month
data['year']=data['date_time'].dt.year
data['day']=data['date_time'].dt.day
data['hour']=data['date_time'].dt.hour
data.head()
# Out:
#   time      date  tempC  windspeedMiles  windspeedKmph  winddirDegree  \
# 0    0  1/1/2019      9               6             10            272
# 1    3  1/1/2019      8               7             11            278
# 2    6  1/1/2019      7               8             12            284
# 3    9  1/1/2019      7               8             13            294
# 4   12  1/1/2019      9               9             15            320
#
#   winddir16Point  weatherCode    weatherDesc  precipMM  ...  pressureInches  \
# 0              W          122       Overcast       0.0  ...              31
# 1              W          116  Partly cloudy       0.0  ...              31
# 2            WNW          113          Sunny       0.0  ...              31
# 3            WNW          116  Partly cloudy       0.0  ...              31
# 4             NW          116  Partly cloudy       0.0  ...              31
#
#    cloudcover  WindGustMiles  WindGustKmph  uvIndex           date_time  \
# ...

# %%
## Before separating the data into two dataframes
## Let's make the seasons column

data['season']=data['month']
data['season']=data['season'].replace([3,4,5],'spring')
data['season']=data['season'].replace([6,7,8],'summer')
data['season']=data['season'].replace([9,10,11],'autumn')
data['season']=data['season'].replace([12,1,2],'winter')

data.head()
# Out:
#   time      date  tempC  windspeedMiles  windspeedKmph  winddirDegree  \
# 0    0  1/1/2019      9               6             10            272
# 1    3  1/1/2019      8               7             11            278
# 2    6  1/1/2019      7               8             12            284
# 3    9  1/1/2019      7               8             13            294
# 4   12  1/1/2019      9               9             15            320
#
#   winddir16Point  weatherCode    weatherDesc  precipMM  ...  cloudcover  \
# 0              W          122       Overcast       0.0  ...         100
# 1              W          116  Partly cloudy       0.0  ...          34
# 2            WNW          113          Sunny       0.0  ...          25
# 3            WNW          116  Partly cloudy       0.0  ...          38
# 4             NW          116  Partly cloudy       0.0  ...          57
#
#    WindGustMiles  WindGustKmph  uvIndex           date_time  month  year  day  \
# ...

# %%
df=data.copy()

# %%
data.index=data['date_time']
data.head()
# Out:
#                     time      date  tempC  windspeedMiles  windspeedKmph  \
# date_time
# 2019-01-01 00:00:00    0  1/1/2019      9               6             10
# 2019-01-01 03:00:00    3  1/1/2019      8               7             11
# 2019-01-01 06:00:00    6  1/1/2019      7               8             12
# 2019-01-01 09:00:00    9  1/1/2019      7               8             13
# 2019-01-01 12:00:00   12  1/1/2019      9               9             15
#
#                      winddirDegree winddir16Point  weatherCode    weatherDesc  \
# date_time
# 2019-01-01 00:00:00            272              W          122       Overcast
# 2019-01-01 03:00:00            278              W          116  Partly cloudy
# 2019-01-01 06:00:00            284            WNW          113          Sunny
# 2019-01-01 09:00:00            294            WNW          116  Partly cloudy
# 2019-01-01 12:00:00            320             NW          116  Partly cloudy
#
# ...

# %%
data=data.drop(['time','date'],axis=1)
data.head()
# Out:
#                      tempC  windspeedMiles  windspeedKmph  winddirDegree  \
# date_time
# 2019-01-01 00:00:00      9               6             10            272
# 2019-01-01 03:00:00      8               7             11            278
# 2019-01-01 06:00:00      7               8             12            284
# 2019-01-01 09:00:00      7               8             13            294
# 2019-01-01 12:00:00      9               9             15            320
#
#                     winddir16Point  weatherCode    weatherDesc  precipMM  \
# date_time
# 2019-01-01 00:00:00              W          122       Overcast       0.0
# 2019-01-01 03:00:00              W          116  Partly cloudy       0.0
# 2019-01-01 06:00:00            WNW          113          Sunny       0.0
# 2019-01-01 09:00:00            WNW          116  Partly cloudy       0.0
# 2019-01-01 12:00:00             NW          116  Partly cloudy       0.0
#
# ...

# %%
data.columns
# Out:
# Index(['tempC', 'windspeedMiles', 'windspeedKmph', 'winddirDegree',
#        'winddir16Point', 'weatherCode', 'weatherDesc', 'precipMM',
#        'precipInches', 'humidity', 'visibility', 'visibilityMiles', 'pressure',
#        'pressureInches', 'cloudcover', 'WindGustMiles', 'WindGustKmph',
#        'uvIndex', 'date_time', 'month', 'year', 'day', 'hour', 'season'],
#       dtype='object')

# %% [markdown]
# As there are multiple columns assigned for the same attribute with just the different unit, including all of them in study makes no sense as they represent the same data. Also keeping them will just increase multicollinearity which is harmful for regression problems.
#
# Following is the list of columns with the same info:
# - windspeedMiles & windspeedKmph
# - precipMM & precipInches
# - visibility & visibilityMiles
# - pressure & pressureInches
# - WindGustMiles & WindGustKmph
#
# Let's drop following and work in metric system:
# - windspeedMiles
# - precipInches
# - visibilityMiles
# - pressureInches
# - WindGustMiles

# %%
data=data.drop(['windspeedMiles','precipInches','visibilityMiles','pressureInches','WindGustMiles'],axis=1)
data.head()
# Out:
#                      tempC  windspeedKmph  winddirDegree winddir16Point  \
# date_time
# 2019-01-01 00:00:00      9             10            272              W
# 2019-01-01 03:00:00      8             11            278              W
# 2019-01-01 06:00:00      7             12            284            WNW
# 2019-01-01 09:00:00      7             13            294            WNW
# 2019-01-01 12:00:00      9             15            320             NW
#
#                      weatherCode    weatherDesc  precipMM  humidity  \
# date_time
# 2019-01-01 00:00:00          122       Overcast       0.0        78
# 2019-01-01 03:00:00          116  Partly cloudy       0.0        85
# 2019-01-01 06:00:00          113          Sunny       0.0        88
# 2019-01-01 09:00:00          116  Partly cloudy       0.0        88
# 2019-01-01 12:00:00          116  Partly cloudy       0.0        81
#
#                      visibility  pressure  cloudcover  WindGustKmph  uvIndex  \
# date_time
# ...

# %%
df=df.drop(['windspeedMiles','precipInches','visibilityMiles','pressureInches','WindGustMiles'],axis=1)
df.head()
# Out:
#   time      date  tempC  windspeedKmph  winddirDegree winddir16Point  \
# 0    0  1/1/2019      9             10            272              W
# 1    3  1/1/2019      8             11            278              W
# 2    6  1/1/2019      7             12            284            WNW
# 3    9  1/1/2019      7             13            294            WNW
# 4   12  1/1/2019      9             15            320             NW
#
#    weatherCode    weatherDesc  precipMM  humidity  ...  pressure  cloudcover  \
# 0          122       Overcast       0.0        78  ...      1035         100
# 1          116  Partly cloudy       0.0        85  ...      1034          34
# 2          113          Sunny       0.0        88  ...      1034          25
# 3          116  Partly cloudy       0.0        88  ...      1034          38
# 4          116  Partly cloudy       0.0        81  ...      1035          57
#
#    WindGustKmph  uvIndex           date_time month  year  day  hour  season
# ...

# %%
hourly=data.resample('H').mean()
daily=data.resample('D').mean()
monthly=data.resample('M').mean()
yearly=data.resample('A').mean()

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Unique Attributes collected in dataset:
# 1. Wind Speed
# 2. Wind Direction
# 3. Weather type
# 4. Precipitation
# 5. Humidity
# 6. Visibility
# 7. Pressure
# 8. Cloud Cover
# 9. Wind Gust
# 10. UV Index
# 11. Date
# 12. Hour
#
# Some questions:
#
# 1. Univariate Analysis:
#
# 2. Bivariate Analysis:
# (with the target variable)
# - How are precipitation and temperature related?
# - How are Wind Speed and temperature related?
# - How are Wind DIrection and temperature related?
# - How are weather type and temperature related?
# - How are humidity and temperature related?
# - How are Visibility and temperature related?
# - How are pressure and temperature related?
# - How are cloud cover and temperature related?
# - How are wind gust and temperature related?
# - How are UV Index and temperature related?
# - How are hour of the day and temperature related?
# - How are season and temperature related?
#
# 3. Multivariate Analysis:
# (with the attributes)
# - **Visibility** : Visibility could be affected by Humidity and Precipitation. Check how are they related.
#
# - **Wind** : Wind flows from high pressure region to low pressure region. The movement of wind and this pressure difference decides the wind direction. However, different region have their own characteristic wind nature. Thus, How are pressure, wind speed and wind direction related?
#
# - **Cloud Cover and weather** : How are the % of cloud cover and different weather types related? For example, during snowfall, clouds contain snow crystals within then. Of course sunny day does not have much of cloud cover.
#
# - **Cloud Cover and precipitation** :  "The type and amount of clouds that commonly form over a region impact the precipitation conditions." Thus , how are precipitation and cloud cover related?
#
# - **Cloud Cover and UV Index** :"CLOUD COVER, if heavy, can block most UV radiation. Thin or broken clouds allow most UV rays through. Puffy, fair-weather clouds deflect rays and can increase UV radiation reaching the surface." What is the relationship between UVIndex and CloudCover?
#
# - **Wind Gust** : "The fundamental difference between the wind gust and wind is duration. A sustained wind is defined as the average wind speed over two minutes. A sudden burst in wind speed is called the wind gusts and typically lasts under 20 seconds". Could it be that a day having high wind speed, face more wind gust?
#
# - **Season**: Season affects all the attributes. Thus, there has to be some sesonal relationship between these attributes and seasons .
#
#
# 4. Time Series

# %%
matrix=data.corr()
f,ax=plt.subplots(figsize=(9,6))
sns.heatmap(matrix,vmax=.8,square=True);

# %%
matrix
# Out:
#                   tempC  windspeedKmph  winddirDegree  weatherCode  precipMM  \
# tempC          1.000000      -0.070885      -0.040982    -0.006694 -0.003878
# windspeedKmph -0.070885       1.000000       0.111514     0.212346  0.148027
# winddirDegree -0.040982       0.111514       1.000000    -0.023590 -0.025059
# weatherCode   -0.006694       0.212346      -0.023590     1.000000  0.523415
# precipMM      -0.003878       0.148027      -0.025059     0.523415  1.000000
# humidity      -0.488262      -0.098056       0.008526     0.243271  0.197980
# visibility     0.141103      -0.070947       0.034100    -0.412957 -0.300984
# pressure       0.074963      -0.408192      -0.161401    -0.356413 -0.266317
# cloudcover    -0.140401       0.271110       0.059784     0.487459  0.259172
# WindGustKmph  -0.154123       0.973439       0.117943     0.237990  0.171532
# uvIndex        0.495109       0.005669      -0.013793    -0.074603 -0.044497
# ...

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# As we could see, the most correlated factors seem to be:
# - uvIndex
# - humidity
# - month
# - WindGustKmph
# - hour of the day
# - visibility
# - cloudcover
#
# Since, correlation does not mean causation. Hence, we'll filter out these factors.
# - uvIndex : it could be causation because more sunrays means more tempC
# - humidity : it could be the causation for high temperature because humid air can hold up more heat than the dry air.
# - month : it could be the cause because tempC changes w.r.t the seasons
# - hour of the day : it could be the cause because tempC is lowest at night and highest at noon due to presence/position of sun.
# - visibility : it could be caused due to some other factors like rain, fog, etc. But visibility cannot be the reason behind reducing temperature.
# - cloudcover : it could be the cause because presence of more clouds results into bouncing back of some of the sun rays back into the space. Hence, the temperature is cooler.
#
# But we could see that precipiptation is not much correlated with the tempC which is weird as if it rains or snows then the temperature is bound to go down. To verify this, let's check the values of precipitation.

# %%
print(data['precipMM'].value_counts())
print(data['precipMM'].unique())
print(len(data['precipMM'].unique()))
# Out:
# 0.0     6405
# 0.1      603
# 0.2      277
# 0.3      193
# 0.4      145
#         ...
# 9.8        1
# 11.5       1
# 8.5        1
# 15.1       1
# 13.8       1
# Name: precipMM, Length: 107, dtype: int64
# [ 0.   0.1  0.2  0.3  0.5  0.7  4.4  3.4  0.4  0.6  0.8  3.3  1.3  1.9
#   2.7  3.8  0.9  3.2  2.9  3.5  1.5  1.6  1.1  1.8  3.1  3.6  4.   6.3
#   3.   7.4  1.2  2.   7.6  2.2  1.7  1.   2.1  3.9  4.8  5.4  6.4  4.5
#   5.2  2.3  4.1  7.8  9.1  9.7 11.2  2.4 19.   8.6 13.8  4.9  2.5  6.5
#   4.6  2.6 12.8 16.3  5.9  5.5  6.9  8.   8.4  1.4  2.8  4.2  8.5  6.2
#   6.6  4.7  8.3 14.3  7.5  9.2  3.7  7.1  9.8  6.1  8.8  5.6 11.6  5.8
#  10.9  6.   7.  10.  14.5  6.7  8.7  5.1 10.8 14.4  6.8 11.5 15.1 20.1
#  11.7 12.3  5.3 18.5 10.3  8.1  7.2  5.7  8.2]
# 107

# %%
plt.subplot(2, 2, 1)
data['precipMM'].plot(figsize=(16,8))
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.precipMM.plot(figsize=(16,8))
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.precipMM.plot(figsize=(16,8))
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.precipMM.plot(figsize=(16,8))
plt.title("Yearly")

plt.suptitle("Precipitation")
plt.show()

# %%
print(len(data[data['precipMM']==0]))
print(len(data[data['precipMM']==0])/data.shape[0])
# Out:
# 6405
# 0.7304972627737226

# %% [markdown]
# From above, we could see that about 73% of the rows has the value of 0 mm precipitation. Apart from this 73%, there are 106 different values, which is less and would not contribute towards our ML model much. Hence, we'll drop this.
#
# Let's check if there is any significant pattern w.r.t the cloudcover throughout the year

# %%
plt.subplot(2, 2, 1)
data['cloudcover'].plot(figsize=(16,8))
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.cloudcover.plot(figsize=(16,8))
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.cloudcover.plot(figsize=(16,8))
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.cloudcover.plot(figsize=(16,8))
plt.title("Yearly")

plt.suptitle("Cloud Cover")
plt.show()

# %%
plt.subplot(2, 2, 1)
data['WindGustKmph'].plot(figsize=(16,8))
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.WindGustKmph.plot(figsize=(16,8))
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.WindGustKmph.plot(figsize=(16,8))
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.WindGustKmph.plot(figsize=(16,8))
plt.title("Yearly")

plt.suptitle("WindGust")
plt.show()

# %%
plt.subplot(2, 2, 1)
data['humidity'].plot(figsize=(16,8))
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.humidity.plot(figsize=(16,8))
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.humidity.plot(figsize=(16,8))
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.humidity.plot(figsize=(16,8))
plt.title("Yearly")

plt.suptitle("Humidity")
plt.show()

# %%
plt.subplot(2, 2, 1)
data['uvIndex'].plot(figsize=(16,8))
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.uvIndex.plot(figsize=(16,8))
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.uvIndex.plot(figsize=(16,8))
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.uvIndex.plot(figsize=(16,8))
plt.title("Yearly")

plt.suptitle("UVIndex")
plt.show()

# %%
plt.subplot(2, 2, 1)
data['tempC'].plot(figsize=(16,8))
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.tempC.plot(figsize=(16,8))
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.tempC.plot(figsize=(16,8))
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.tempC.plot(figsize=(16,8))
plt.title("Yearly")

plt.suptitle("Temperature")
plt.show()

# %% [markdown]
# As we could see from above graph, following have a clear variation with respect to the season of the year:
# - uvIndex
# - humidity
# - tempC
#
# While the following are much more random and do not seem to follow much regular relation with time:
# - WindGustKmph
# - cloudcover
#
# So, we'll use following factors to carry out further analysis:
# - uvIndex
# - humidity
# - tempC
# - and date time (with frequency adjustments)

# %% [markdown]
# ### Bivariate Analysis

# %%
f, axes = plt.subplots(4)
plt.subplot(2, 2, 1)
data['tempC'].plot(figsize=(16,8))
data['humidity'].plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.tempC.plot(figsize=(16,8))
daily.humidity.plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.tempC.plot(figsize=(16,8))
monthly.humidity.plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.tempC.plot(figsize=(16,8))
yearly.humidity.plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Yearly")

plt.suptitle("Humidity vs. Temperature")
plt.show()

# %%
f, axes = plt.subplots(4)
plt.subplot(2, 2, 1)
data['tempC'].plot(figsize=(16,8))
data['uvIndex'].plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Hourly")
plt.subplot(2, 2, 2)
daily.tempC.plot(figsize=(16,8))
daily.uvIndex.plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Daily")
plt.subplot(2, 2, 3)
monthly.tempC.plot(figsize=(16,8))
monthly.uvIndex.plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Monthly")
plt.subplot(2, 2, 4)
yearly.tempC.plot(figsize=(16,8))
yearly.uvIndex.plot(figsize=(16,8))
plt.legend(loc="upper left")
plt.title("Yearly")

plt.suptitle("uvIndex vs. Temperature")
plt.show()

# %%
data1=data[['tempC','humidity','uvIndex']]
data1.head()
# Out:
#                      tempC  humidity  uvIndex
# date_time
# 2019-01-01 00:00:00      9        78        1
# 2019-01-01 03:00:00      8        85        1
# 2019-01-01 06:00:00      7        88        3
# 2019-01-01 09:00:00      7        88        3
# 2019-01-01 12:00:00      9        81        3

# %% [markdown]
# ## Conclusions from EDA
# - Humidity and UV Index are the factors that have the highest and most relevant (predictible) relationship with temperature on a day.
# - Humidity and UV Index too have seasonal variation nature like temperature.
# - Precipitation is very less. Hence, we assume that the place to which the data belongs to is dry comparitively. Since this data won't be of much help towards our ML model, hence we drop precipitation.
# - Cloud cover and windgust follow very random nature and seem to change a lot within hours in a day.
# - Other variables do not have much of correlation w.r.t the temperature.
#
# ### About the hypothesis
# Following hypothesis are confirmed from EDA
# - Humidity and temperature cycles tend to have same nature but are a little off. They are slightly indirectly related. As humidity increases, temperature decreases.
# - As UV Index increases, temperature also increases.
# - Temperature, Humidity and UV Index follow a cycle that repeats itself after interval of 1 year.

# %% [markdown]
# ## Model Building
#
# Model 1: When we have uvIndex and humidity, we predict the value of tempC (data sampled at every 3hrs) using regression techniques.
#
# Model 2: We predict the value of temperature (pure time series (univarite)) sampled at 3 hrs per day.
#
# Model 3: We predict the values of humidity and uvIndex (pure time series (univariate)) sampled at 3 hrs per day and then use them and model 1 to predict the value of temperature that day.
#
# Model 4: We predict the values of humidity and uvIndex (pure time series (univariate)) sampled once per day and then use them and model 1 to predict the value of temperature that day.

# %% [markdown]
# ## Model 1

# %%
resample = data1.resample('D')
daily_mean = resample.mean()

# %%
daily_mean.head()
# Out:
#             tempC  humidity  uvIndex
# date_time
# 2019-01-01  8.250    80.500    1.875
# 2019-01-02  4.625    74.250    1.750
# 2019-01-03  3.625    75.250    1.500
# 2019-01-04  2.875    76.375    1.375
# 2019-01-05  4.375    82.625    1.500

# %%
daily_mean.plot()

# %%
daily_mean['target']=daily_mean.shift(-1)['tempC']

# %%
daily_mean.head()
# Out:
#             tempC  humidity  uvIndex  target
# date_time
# 2019-01-01  8.250    80.500    1.875   4.625
# 2019-01-02  4.625    74.250    1.750   3.625
# 2019-01-03  3.625    75.250    1.500   2.875
# 2019-01-04  2.875    76.375    1.375   4.375
# 2019-01-05  4.375    82.625    1.500   6.000

# %%
daily_mean.dtypes
# Out:
# tempC       float64
# humidity    float64
# uvIndex     float64
# target      float64
# dtype: object

# %%
daily_mean.index = pd.to_datetime(daily_mean.index)

# %%
daily_mean=daily_mean.iloc[:-1,:].copy()

# %%
daily_mean.tail()
# Out:
#              tempC  humidity  uvIndex  target
# date_time
# 2021-12-26   6.750    94.750    1.500   8.375
# 2021-12-27   8.375    93.375    1.625   8.875
# 2021-12-28   8.875    83.750    1.875  11.750
# 2021-12-29  11.750    86.500    2.000  13.000
# 2021-12-30  13.000    89.375    2.000  12.500

# %%
0.8*daily_mean.shape[0]
# Out:
# 876.0

# %%
daily_mean.shape[0]
# Out:
# 1095

# %%
daily_mean.head()
# Out:
#             tempC  humidity  uvIndex  target
# date_time
# 2019-01-01  8.250    80.500    1.875   4.625
# 2019-01-02  4.625    74.250    1.750   3.625
# 2019-01-03  3.625    75.250    1.500   2.875
# 2019-01-04  2.875    76.375    1.375   4.375
# 2019-01-05  4.375    82.625    1.500   6.000

# %%
z=daily_mean['tempC']

# %%
daily_mean=daily_mean.drop('tempC',axis=1)

# %%
x_train=daily_mean.iloc[:876,:-1]
x_test=daily_mean.iloc[876:,:-1]
y_train=daily_mean.iloc[:876,-1]
y_test=daily_mean.iloc[876:,-1]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(x_train, y_train)
pred=reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
mse(y_test,pred,squared=False)
# Out:
# 2.6084222894747566

# %%
pred_comp=reg.predict(daily_mean.iloc[:,:-1])

# %%
daily_mean['predicted']=pred_comp
daily_mean.head(20)
# Out:
#             humidity  uvIndex  target  predicted
# date_time
# 2019-01-01    80.500    1.875   4.625   9.387318
# 2019-01-02    74.250    1.750   3.625   8.037265
# 2019-01-03    75.250    1.500   2.875   6.008512
# 2019-01-04    76.375    1.375   4.375   5.025217
# 2019-01-05    82.625    1.500   6.000   6.375269
# 2019-01-06    86.875    1.500   7.250   6.586621
# 2019-01-07    90.875    1.500   7.125   6.785540
# 2019-01-08    74.625    2.000   4.375  10.134396
# 2019-01-09    72.375    1.500   3.625   5.865539
# 2019-01-10    81.375    1.000   6.625   2.156142
# 2019-01-11    88.875    1.750   7.875   8.764563
# 2019-01-12    83.625    1.500  10.125   6.424999
# 2019-01-13    76.875    1.750   7.750   8.167806
# 2019-01-14    71.250    1.750   6.750   7.888076
# 2019-01-15    85.375    1.625   8.750   7.551268
# 2019-01-16    81.125    1.500   4.625   6.300675
# 2019-01-17    65.625    1.250   3.625   3.451380
# 2019-01-18    63.375    1.375   4.250   4.378730
# ...

# %%
daily_mean[['target','predicted']].plot()

# %% [markdown]
# ### Model 2,3 &4

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
resampleM = data1.resample('M')
monthly_mean = resampleM.mean()
df_h1=monthly_mean.copy()
df_h1=df_h1.drop(['uvIndex','tempC'],axis=1)
df_t1=monthly_mean.copy()
df_t1=df_t1.drop(['uvIndex','humidity'],axis=1)
df_u1=monthly_mean.copy()
df_u1=df_u1.drop(['tempC','humidity'],axis=1)

# %%
adf_test(df_h1['humidity'])
# Out:
# ADF Statistics: -3.135348302236733
# p- value: 0.02404546445223408
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
adf_test(df_t1['tempC'])
# Out:
# ADF Statistics: -0.6294096015880944
# p- value: 0.8641972396766866
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
adf_test(df_u1['uvIndex'])
# Out:
# ADF Statistics: -1.5650223545614863
# p- value: 0.5011361274591339
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# ### For Humidity

# %%
acf_h1 = plot_acf(df_h1["humidity"].dropna())

# %%
pacf_h1 = plot_pacf(df_h1["humidity"].dropna())

# %%
df_h1.plot()

# %%
monthly_mean.shape[0]*0.8
# Out:
# 28.8

# %%
x_train=df_h1.iloc[:29]
x_test=df_h1.iloc[29:]

# %%
x_train.tail()
# Out:
#              humidity
# date_time
# 2021-01-31  82.241935
# 2021-02-28  76.776786
# 2021-03-31  67.580645
# 2021-04-30  62.504167
# 2021-05-31  74.193548

# %%
x_test.head()
# Out:
#              humidity
# date_time
# 2021-06-30  73.720833
# 2021-07-31  73.173387
# 2021-08-31  68.858871
# 2021-09-30  66.995833
# 2021-10-31  75.951613

# %%
x_test.tail()
# Out:
#              humidity
# date_time
# 2021-08-31  68.858871
# 2021-09-30  66.995833
# 2021-10-31  75.951613
# 2021-11-30  77.212500
# 2021-12-31  83.701613

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model_SARIMA=SARIMAX(x_train['humidity'],order=(2,0,2),seasonal_order=(2,0,2,9))

model_SARIMA_fit=model_SARIMA.fit()
model_SARIMA_fit.summary()
# Out:
# c:\users\anshika\appdata\local\programs\python\python37\lib\site-packages\statsmodels\base\model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                          humidity   No. Observations:                   29
# Model:             SARIMAX(2, 0, 2)x(2, 0, 2, 9)   Log Likelihood                 -90.424
# Date:                           Sun, 13 Mar 2022   AIC                            198.847
# Time:                                   09:26:01   BIC                            211.153
# Sample:                               01-31-2019   HQIC                           202.701
#                                     - 05-31-2021
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
from datetime import datetime
pred_Sarima=model_SARIMA_fit.predict(start=datetime(2021,6,30),end=datetime(2021,12,31))
residuals=x_test['humidity']-pred_Sarima
residuals.plot()

# %%
x_test['Predicted_SARIMA']=pred_Sarima
x_test[['Predicted_SARIMA','humidity']].plot()
print(mse(x_test['humidity'],pred_Sarima,squared=False))
# Out:
# 5.334296158052404

# %%
mse(x_test['humidity'],pred_Sarima,squared=False)
# Out:
# 5.334296158052404

# %%
df_h_test=x_test

# %% [markdown]
# ### For uvIndex

# %%
acf_u1 = plot_acf(df_u1["uvIndex"].dropna())

# %%
pacf_u1 = plot_pacf(df_u1["uvIndex"].dropna())

# %%
df_u1.plot()

# %%
x_train=df_u1.iloc[:29]
x_test=df_u1.iloc[29:]

# %%
model_SARIMA=SARIMAX(x_train['uvIndex'],order=(2,0,2),seasonal_order=(2,0,2,9))

model_SARIMA_fit=model_SARIMA.fit()
model_SARIMA_fit.summary()
# Out:
# c:\users\anshika\appdata\local\programs\python\python37\lib\site-packages\statsmodels\base\model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                           uvIndex   No. Observations:                   29
# Model:             SARIMAX(2, 0, 2)x(2, 0, 2, 9)   Log Likelihood                  -3.855
# Date:                           Sun, 13 Mar 2022   AIC                             25.711
# Time:                                   09:26:02   BIC                             38.017
# Sample:                               01-31-2019   HQIC                            29.565
#                                     - 05-31-2021
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
pred_Sarima=model_SARIMA_fit.predict(start=datetime(2021,6,30),end=datetime(2021,12,31))
residuals=x_test['uvIndex']-pred_Sarima
residuals.plot()

# %%
x_test['Predicted_SARIMA']=pred_Sarima
x_test[['Predicted_SARIMA','uvIndex']].plot()
print(mse(x_test['uvIndex'],pred_Sarima,squared=False))
# Out:
# 0.45713136953364564

# %%
mse(x_test['uvIndex'],pred_Sarima,squared=False)
# Out:
# 0.45713136953364564

# %%
df_u_test=x_test

# %% [markdown]
# ### For tempC

# %%
acf_t1 = plot_acf(df_t1["tempC"].dropna())

# %%
pacf_t1 = plot_pacf(df_t1["tempC"].dropna())

# %%
df_t1.plot()

# %%
x_train=df_t1.iloc[:29]
x_test=df_t1.iloc[29:]

# %%
model_SARIMA=SARIMAX(x_train['tempC'],order=(2,0,5),seasonal_order=(2,0,5,9))

model_SARIMA_fit=model_SARIMA.fit()
model_SARIMA_fit.summary()
# Out:
# c:\users\anshika\appdata\local\programs\python\python37\lib\site-packages\statsmodels\base\model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                             tempC   No. Observations:                   29
# Model:             SARIMAX(2, 0, 5)x(2, 0, 5, 9)   Log Likelihood                 -61.320
# Date:                           Sun, 13 Mar 2022   AIC                            152.639
# Time:                                   09:26:06   BIC                            173.149
# Sample:                               01-31-2019   HQIC                           159.063
#                                     - 05-31-2021
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
pred_Sarima=model_SARIMA_fit.predict(start=datetime(2021,6,30),end=datetime(2021,12,31))
residuals=x_test['tempC']-pred_Sarima
residuals.plot()

# %%
x_test['Predicted_SARIMA']=pred_Sarima
x_test[['Predicted_SARIMA','tempC']].plot()
print(mse(x_test['tempC'],pred_Sarima,squared=False))
# Out:
# 5.070164918653099

# %%
mse(x_test['tempC'],pred_Sarima,squared=False)
# Out:
# 5.070164918653099

# %%
df_t_test=x_test

# %%
data3=df_t_test.copy()
data3['humidity']=df_h_test['Predicted_SARIMA']
data3['uvIndex']=df_u_test['Predicted_SARIMA']
#data3['temp']=df_t_test['Predicted_SARIMA']
data3=data3.drop('Predicted_SARIMA',axis=1)

# %%
data3.head()
# Out:
#                 tempC   humidity   uvIndex
# date_time
# 2021-06-30  17.441667  77.565983  2.239881
# 2021-07-31  18.411290  75.002168  2.406309
# 2021-08-31  17.725806  75.720521  2.481472
# 2021-09-30  17.287500  75.984407  2.560599
# 2021-10-31  13.056452  76.586191  2.592262

# %%
data3.plot()

# %%
data3.columns
# Out:
# Index(['tempC', 'humidity', 'uvIndex'], dtype='object')

# %%
data3['target']=data3.shift(-1)['tempC']
data3=data3.iloc[:-1,:].copy()
data3.tail()
# Out:
#                 tempC   humidity   uvIndex     target
# date_time
# 2021-07-31  18.411290  75.002168  2.406309  17.725806
# 2021-08-31  17.725806  75.720521  2.481472  17.287500
# 2021-09-30  17.287500  75.984407  2.560599  13.056452
# 2021-10-31  13.056452  76.586191  2.592262   8.825000
# 2021-11-30   8.825000  77.961594  2.483939   7.379032

# %%
x_test=data3[[ 'humidity', 'uvIndex']]
y_test=data3['target']

# %%
y_test
# Out:
# date_time
# 2021-06-30    18.411290
# 2021-07-31    17.725806
# 2021-08-31    17.287500
# 2021-09-30    13.056452
# 2021-10-31     8.825000
# 2021-11-30     7.379032
# Freq: M, Name: target, dtype: float64

# %%
#reg = LinearRegression().fit(x_train, y_train)
pred3=reg.predict(x_test)
pred3
# Out:
# array([12.2750081 , 13.53118163, 14.19180295, 14.86278226, 15.15595331,
#        14.3237584 ])

# %%
print(mse(y_test,pred3,squared=False))
data3['predicted']=pred3
data3[['target','predicted']].plot()
# Out:
# 5.105637383106195
